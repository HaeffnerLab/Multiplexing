# %% [markdown]
# ### Data on 20240111

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# g2_data_path
g2_data_path = "D:/Data Storage/Multiplexing/g2_data/"

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

all_raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 16-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-30_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 12-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 13-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-39_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 18-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-29_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-47_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 12-42_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 13-10_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 9-38_9_ions.1.ttbin"]

# raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
#             "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
#             "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
#             "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
#             "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin",
#             "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin"]

raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin"]

# all_raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin"]

# Start_time1 = 0.0
# End_time1 = 2
# Start_time2 = 13.0
# End_time2 = 15
# Start_time3 = 25.0
# End_time3 = 27
# Start_time4 = 37.0
# End_time4 = 39
# Start_time5 = 49.0
# End_time5 = 51
# Start_time6 = 60.5
# End_time6 = 62.5
# Start_time7 = 72.0
# End_time7 = 74
# Start_time8 = 85.0
# End_time8 = 87.0
# Start_time9 = 97.5
# End_time9 = 99.5

# Time filtering window length
# time_filtering = (1 + offset) * 1e6
time_filtering = (0.3) * 1e6

offset = 0
# offset = 0

Start_time1 = 0.7
End_time1 = Start_time1 + time_filtering/1e6
Start_time2 = 13.7
End_time2 = Start_time2 + time_filtering/1e6
Start_time3 = 25.7
End_time3 = Start_time3 + time_filtering/1e6
Start_time4 = 37.7
End_time4 = Start_time4 + time_filtering/1e6
Start_time5 = 49.7
End_time5 = Start_time5 + time_filtering/1e6
Start_time6 = 61.23
End_time6 = Start_time6 + time_filtering/1e6
Start_time7 = 72.7
End_time7 = Start_time7 + time_filtering/1e6
Start_time8 = 85.2
End_time8 = Start_time8 + time_filtering/1e6
Start_time9 = 98.18
End_time9 = Start_time9 + time_filtering/1e6

# Number of bins and binwidth for correlation measurement
number = int(750 * 1.7)
binwidth_corr = 200 * 1e3

# Number of bins and binwidth for histogram measurement
number_bins = 460 * 16
binwidth_hist = 125 * 1e3 / 8

# The defination of all channels
trigger_channel = 2
PMT_channel1 = 1
PMT_channel2 = 3

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                             open_gate_channel2,
                                                             open_gate_channel3,
                                                             open_gate_channel4,
                                                             open_gate_channel5,
                                                             open_gate_channel6,
                                                             open_gate_channel7,
                                                             open_gate_channel8,
                                                             open_gate_channel9])
    open_gate_channel = open_gate.getChannel()

    close_gate = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel, delay=time_filtering)
    close_gate_channel = close_gate.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

    # np.save('corr.getData_'+formatted_string+'.npy', corr.getData())
    # np.save('corr.getIndex_'+formatted_string+'.npy', corr.getIndex())

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

# Plot the g(2) function
# np.save('data_final_corr_meas_'+formatted_string+'.npy', final_result)
# np.save('index_final_corr_meas_'+formatted_string+'.npy', index)

plt.figure(figsize = (10, 5))
plt.plot(index, final_result)
plt.title("9 ions coincidence counts", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

title = "Histogram with 9 ions and addressing laser"
'''plt.plot'''
plt.figure(figsize = (20, 10))
plt.rc('font',family='STIXGeneral')
plt.scatter(hist_index, final_hist, c='C0')
plt.plot(hist_index, final_hist, c='C0')

plt.axvline(Start_time1, color='r')
print("Start time =", Start_time1, "us")
plt.axvline(End_time1, color='r')
print("End time =", End_time1, "us")

plt.axvline(Start_time2, color='r')
print("Start time =", Start_time2, "us")
plt.axvline(End_time2, color='r')
print("End time =", End_time2, "us")

plt.axvline(Start_time3, color='r')
print("Start time =", Start_time3, "us")
plt.axvline(End_time3, color='r')
print("End time =", End_time3, "us")

plt.axvline(Start_time4, color='r')
print("Start time =", Start_time4, "us")
plt.axvline(End_time4, color='r')
print("End time =", End_time4, "us")

plt.axvline(Start_time5, color='r')
print("Start time =", Start_time5, "us")
plt.axvline(End_time5, color='r')
print("End time =", End_time5, "us")

plt.axvline(Start_time6, color='r')
print("Start time =", Start_time6, "us")
plt.axvline(End_time6, color='r')
print("End time =", End_time6, "us")

plt.axvline(Start_time7, color='r')
print("Start time =", Start_time7, "us")
plt.axvline(End_time7, color='r')
print("End time =", End_time7, "us")

plt.axvline(Start_time8, color='r')
print("Start time =", Start_time8, "us")
plt.axvline(End_time8, color='r')
print("End time =", End_time8, "us")

plt.axvline(Start_time9, color='r')
print("Start time =", Start_time9, "us")
plt.axvline(End_time9, color='r')
print("End time =", End_time9, "us")

# plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.title("all ions hist", fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
# plt.xlim(Start_time9-2, End_time9+2)
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
# plt.savefig('./'+file_name_PMT+' _data.jpg')
plt.show()
# Out:
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Start time = 0.7 us
# End time = 1.0 us
# Start time = 13.7 us
# End time = 14.0 us
# Start time = 25.7 us
# End time = 26.0 us
# Start time = 37.7 us
# End time = 38.0 us
# Start time = 49.7 us
# End time = 50.0 us
# Start time = 61.23 us
# End time = 61.529999999999994 us
# Start time = 72.7 us
# End time = 73.0 us
# Start time = 85.2 us
# End time = 85.5 us
# Start time = 98.18 us
# End time = 98.48 us

# %%
# Redefine the windows for binning based on the corrected start and end times
# Load the index and the data from the provided .npy files
# index_data = np.load('index_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
# counts_data = np.load('data_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
counts_data = final_result
index_data = index

bin_windows = [
    (-98.0, -92.0),
    (-86.0, -80.0),
    (-74.0, -68.0),
    (-62.0, -56.0),
    (-50.0, -44.0),
    (-39.0, -32.0),
    (-27.0, -21.0),
    (-15.0, -9.0),
    (-2.0, 2.0),
    (9.0, 15.0),
    (21.0, 27.0),
    (33.0, 39.0),
    (43.0, 51.0),
    (56.0, 62.0),
    (68.0, 74.0),
    (80.0, 86.0),
    (92.0, 98.0)
]

np.save("non_binned_counts_20240111", counts_data)

# counts_data = np.load("non_binned_counts_20240111.npy") + \
#               np.load("non_binned_counts_20240112.npy") + \
#               np.load("non_binned_counts_20240113.npy") + \
#               np.load("non_binned_counts_20240114.npy") + \
#               np.load("non_binned_counts_20240115.npy")

plt.figure(figsize = (10, 5))
plt.rc('font',family='STIXGeneral')
plt.plot(index_data, counts_data, c='C0')
plt.scatter(index_data, counts_data, c='C0')

for i in range(len(bin_windows)):
    plt.axvline(bin_windows[i][0], color='r')
    print("Start time =", bin_windows[i][0], "us")
    plt.axvline(bin_windows[i][1], color='r')
    print("End time =", bin_windows[i][1], "us")

plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
plt.show()

# Re-bin the data according to the new specified windows
binned_counts = []

for start, end in bin_windows:
    # Find indices where the delay is within the current window (considering negative windows)
    indices_in_window = (index_data >= start) & (index_data <= end) if start < end else (index_data <= start) & (index_data >= end)
    # Sum the counts for these indices
    counts_sum = counts_data[indices_in_window].sum()
    binned_counts.append(counts_sum)

np.save("binned_counts_20240111", binned_counts)

# binned_counts = np.load("binned_counts_20240111.npy") + \
#                 np.load("binned_counts_20240112.npy") + \
#                 np.load("binned_counts_20240113.npy") + \
#                 np.load("binned_counts_20240114.npy") + \
#                 np.load("binned_counts_20240115.npy")

# Re-plotting the binned data with the corrected windows
plt.figure(figsize=(10, 6))
# x_labels = [f"{start}-{end}" for (start, end) in bin_windows]
# window_num = np.array(range(19)) - 9
# x_labels = [f"window {i}" for i in window_num]
x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=17)

print(len(x_labels))
print(len(binned_counts))

plt.bar(x_labels, binned_counts, color='C0', width=2)

x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=200)
plt.bar(x_labels, np.zeros(200), color='C0', width=2)

# plt.plot(x_labels, binned_counts, color='C0')
plt.xlabel('Delay time (us)')
plt.ylabel('Correlation counts')
plt.title('Single photon correlation counts', fontdict={'family' : 'STIXGeneral', 'size':25})
# plt.xticks(x_labels[::3])   #,  rotation='vertical'
# plt.xticks(rotation=90)  # Rotate the labels to prevent overlap due to increased number of bins
plt.tight_layout()  # Adjust the plot to ensure everything fits without overlapping
plt.show()
print(binned_counts)
# Out:
# Start time = -98.0 us
# End time = -92.0 us
# Start time = -86.0 us
# End time = -80.0 us
# Start time = -74.0 us
# End time = -68.0 us
# Start time = -62.0 us
# End time = -56.0 us
# Start time = -50.0 us
# End time = -44.0 us
# Start time = -39.0 us
# End time = -32.0 us
# Start time = -27.0 us
# End time = -21.0 us
# Start time = -15.0 us
# End time = -9.0 us
# Start time = -2.0 us
# End time = 2.0 us
# Start time = 9.0 us
# End time = 15.0 us
# Start time = 21.0 us
# End time = 27.0 us
# Start time = 33.0 us
# End time = 39.0 us
# Start time = 43.0 us
# End time = 51.0 us
# Start time = 56.0 us
# End time = 62.0 us
# Start time = 68.0 us
# End time = 74.0 us
# Start time = 80.0 us
# End time = 86.0 us
# Start time = 92.0 us
# End time = 98.0 us
# 17
# 17
# [2.0, 2.0, 0.0, 3.0, 0.0, 6.0, 2.0, 4.0, 0.0, 2.0, 9.0, 4.0, 6.0, 6.0, 2.0, 0.0, 2.0]

# %% [markdown]
# ### Data on 20240112

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# g2_data_path
g2_data_path = "D:/Data Storage/Multiplexing/g2_data/"

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

all_raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 16-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-30_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 12-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 13-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-39_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 18-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-29_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-47_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 12-42_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 13-10_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 9-38_9_ions.1.ttbin"]

# raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
#             "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
#             "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
#             "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
#             "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
#             "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin",
#             "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin"]

raw_data = ["filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 16-27_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-30_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin"]

# all_raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin"]
# raw_data = ["filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin"]

# Start_time1 = 0.0
# End_time1 = 2
# Start_time2 = 13.0
# End_time2 = 15
# Start_time3 = 25.0
# End_time3 = 27
# Start_time4 = 37.0
# End_time4 = 39
# Start_time5 = 49.0
# End_time5 = 51
# Start_time6 = 60.5
# End_time6 = 62.5
# Start_time7 = 72.0
# End_time7 = 74
# Start_time8 = 85.0
# End_time8 = 87.0
# Start_time9 = 97.5
# End_time9 = 99.5

# Time filtering window length
# time_filtering = (1 + offset) * 1e6
time_filtering = (0.3) * 1e6

offset = 0
# offset = 0

Start_time1 = 0.7
End_time1 = Start_time1 + time_filtering/1e6
Start_time2 = 13.7
End_time2 = Start_time2 + time_filtering/1e6
Start_time3 = 25.7
End_time3 = Start_time3 + time_filtering/1e6
Start_time4 = 37.7
End_time4 = Start_time4 + time_filtering/1e6
Start_time5 = 49.7
End_time5 = Start_time5 + time_filtering/1e6
Start_time6 = 61.2
End_time6 = Start_time6 + time_filtering/1e6
Start_time7 = 72.7
End_time7 = Start_time7 + time_filtering/1e6
Start_time8 = 85.2
End_time8 = Start_time8 + time_filtering/1e6
Start_time9 = 98.18
End_time9 = Start_time9 + time_filtering/1e6

# Number of bins and binwidth for correlation measurement
number = int(750 * 1.7)
binwidth_corr = 200 * 1e3

# Number of bins and binwidth for histogram measurement
number_bins = 460 * 16
binwidth_hist = 125 * 1e3 / 8

# The defination of all channels
trigger_channel = 2
PMT_channel1 = 1
PMT_channel2 = 3

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                             open_gate_channel2,
                                                             open_gate_channel3,
                                                             open_gate_channel4,
                                                             open_gate_channel5,
                                                             open_gate_channel6,
                                                             open_gate_channel7,
                                                             open_gate_channel8,
                                                             open_gate_channel9])
    open_gate_channel = open_gate.getChannel()

    close_gate = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel, delay=time_filtering)
    close_gate_channel = close_gate.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

    # np.save('corr.getData_'+formatted_string+'.npy', corr.getData())
    # np.save('corr.getIndex_'+formatted_string+'.npy', corr.getIndex())

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

# Plot the g(2) function
# np.save('data_final_corr_meas_'+formatted_string+'.npy', final_result)
# np.save('index_final_corr_meas_'+formatted_string+'.npy', index)

plt.figure(figsize = (10, 5))
plt.plot(index, final_result)
plt.title("9 ions coincidence counts", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

title = "Histogram with 9 ions and addressing laser"
'''plt.plot'''
plt.figure(figsize = (20, 10))
plt.rc('font',family='STIXGeneral')
plt.scatter(hist_index, final_hist, c='C0')
plt.plot(hist_index, final_hist, c='C0')

plt.axvline(Start_time1, color='r')
print("Start time =", Start_time1, "us")
plt.axvline(End_time1, color='r')
print("End time =", End_time1, "us")

plt.axvline(Start_time2, color='r')
print("Start time =", Start_time2, "us")
plt.axvline(End_time2, color='r')
print("End time =", End_time2, "us")

plt.axvline(Start_time3, color='r')
print("Start time =", Start_time3, "us")
plt.axvline(End_time3, color='r')
print("End time =", End_time3, "us")

plt.axvline(Start_time4, color='r')
print("Start time =", Start_time4, "us")
plt.axvline(End_time4, color='r')
print("End time =", End_time4, "us")

plt.axvline(Start_time5, color='r')
print("Start time =", Start_time5, "us")
plt.axvline(End_time5, color='r')
print("End time =", End_time5, "us")

plt.axvline(Start_time6, color='r')
print("Start time =", Start_time6, "us")
plt.axvline(End_time6, color='r')
print("End time =", End_time6, "us")

plt.axvline(Start_time7, color='r')
print("Start time =", Start_time7, "us")
plt.axvline(End_time7, color='r')
print("End time =", End_time7, "us")

plt.axvline(Start_time8, color='r')
print("Start time =", Start_time8, "us")
plt.axvline(End_time8, color='r')
print("End time =", End_time8, "us")

plt.axvline(Start_time9, color='r')
print("Start time =", Start_time9, "us")
plt.axvline(End_time9, color='r')
print("End time =", End_time9, "us")

# plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.title("all ions hist", fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
# plt.xlim(Start_time1-2, End_time1+2)
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
# plt.savefig('./'+file_name_PMT+' _data.jpg')
plt.show()
# Out:
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Start time = 0.7 us
# End time = 1.0 us
# Start time = 13.7 us
# End time = 14.0 us
# Start time = 25.7 us
# End time = 26.0 us
# Start time = 37.7 us
# End time = 38.0 us
# Start time = 49.7 us
# End time = 50.0 us
# Start time = 61.2 us
# End time = 61.5 us
# Start time = 72.7 us
# End time = 73.0 us
# Start time = 85.2 us
# End time = 85.5 us
# Start time = 98.18 us
# End time = 98.48 us

# %%
# Redefine the windows for binning based on the corrected start and end times
# Load the index and the data from the provided .npy files
# index_data = np.load('index_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
# counts_data = np.load('data_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
counts_data = final_result
index_data = index

bin_windows = [
    (-98.0, -92.0),
    (-86.0, -80.0),
    (-74.0, -68.0),
    (-62.0, -56.0),
    (-50.0, -44.0),
    (-39.0, -32.0),
    (-27.0, -21.0),
    (-15.0, -9.0),
    (-2.0, 2.0),
    (9.0, 15.0),
    (21.0, 27.0),
    (33.0, 39.0),
    (43.0, 51.0),
    (56.0, 62.0),
    (68.0, 74.0),
    (80.0, 86.0),
    (92.0, 98.0)
]

np.save("non_binned_counts_20240112", counts_data)

# counts_data = np.load("non_binned_counts_20240111.npy") + \
#               np.load("non_binned_counts_20240112.npy") + \
#               np.load("non_binned_counts_20240113.npy") + \
#               np.load("non_binned_counts_20240114.npy") + \
#               np.load("non_binned_counts_20240115.npy")

plt.figure(figsize = (10, 5))
plt.rc('font',family='STIXGeneral')
plt.plot(index_data, counts_data, c='C0')
plt.scatter(index_data, counts_data, c='C0')

for i in range(len(bin_windows)):
    plt.axvline(bin_windows[i][0], color='r')
    print("Start time =", bin_windows[i][0], "us")
    plt.axvline(bin_windows[i][1], color='r')
    print("End time =", bin_windows[i][1], "us")

plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
plt.show()

# Re-bin the data according to the new specified windows
binned_counts = []

for start, end in bin_windows:
    # Find indices where the delay is within the current window (considering negative windows)
    indices_in_window = (index_data >= start) & (index_data <= end) if start < end else (index_data <= start) & (index_data >= end)
    # Sum the counts for these indices
    counts_sum = counts_data[indices_in_window].sum()
    binned_counts.append(counts_sum)

np.save("binned_counts_20240112", binned_counts)

# binned_counts = np.load("binned_counts_20240111.npy") + \
#                 np.load("binned_counts_20240112.npy") + \
#                 np.load("binned_counts_20240113.npy") + \
#                 np.load("binned_counts_20240114.npy") + \
#                 np.load("binned_counts_20240115.npy")

# Re-plotting the binned data with the corrected windows
plt.figure(figsize=(10, 6))
# x_labels = [f"{start}-{end}" for (start, end) in bin_windows]
# window_num = np.array(range(19)) - 9
# x_labels = [f"window {i}" for i in window_num]
x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=17)

print(len(x_labels))
print(len(binned_counts))

plt.bar(x_labels, binned_counts, color='C0', width=2)

x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=200)
plt.bar(x_labels, np.zeros(200), color='C0', width=2)

# plt.plot(x_labels, binned_counts, color='C0')
plt.xlabel('Delay time (us)')
plt.ylabel('Correlation counts')
plt.title('Single photon correlation counts', fontdict={'family' : 'STIXGeneral', 'size':25})
# plt.xticks(x_labels[::3])   #,  rotation='vertical'
# plt.xticks(rotation=90)  # Rotate the labels to prevent overlap due to increased number of bins
plt.tight_layout()  # Adjust the plot to ensure everything fits without overlapping
plt.show()
print(binned_counts)
# Out:
# Start time = -98.0 us
# End time = -92.0 us
# Start time = -86.0 us
# End time = -80.0 us
# Start time = -74.0 us
# End time = -68.0 us
# Start time = -62.0 us
# End time = -56.0 us
# Start time = -50.0 us
# End time = -44.0 us
# Start time = -39.0 us
# End time = -32.0 us
# Start time = -27.0 us
# End time = -21.0 us
# Start time = -15.0 us
# End time = -9.0 us
# Start time = -2.0 us
# End time = 2.0 us
# Start time = 9.0 us
# End time = 15.0 us
# Start time = 21.0 us
# End time = 27.0 us
# Start time = 33.0 us
# End time = 39.0 us
# Start time = 43.0 us
# End time = 51.0 us
# Start time = 56.0 us
# End time = 62.0 us
# Start time = 68.0 us
# End time = 74.0 us
# Start time = 80.0 us
# End time = 86.0 us
# Start time = 92.0 us
# End time = 98.0 us
# 17
# 17
# [16.0, 21.0, 12.0, 17.0, 25.0, 27.0, 25.0, 32.0, 2.0, 25.0, 27.0, 17.0, 20.0, 15.0, 30.0, 7.0, 10.0]

# %% [markdown]
# ### Data on 20240113

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# Start_time1 = 0.0
# End_time1 = 2
# Start_time2 = 13.0
# End_time2 = 15
# Start_time3 = 25.0
# End_time3 = 27
# Start_time4 = 37.0
# End_time4 = 39
# Start_time5 = 49.0
# End_time5 = 51
# Start_time6 = 60.5
# End_time6 = 62.5
# Start_time7 = 72.0
# End_time7 = 74
# Start_time8 = 85.0
# End_time8 = 87.0
# Start_time9 = 97.5
# End_time9 = 99.5

time_filtering = (0.3) * 1e6

offset = 0

Start_time1 = 0.7
End_time1 = Start_time1 + time_filtering/1e6
Start_time2 = 13.7
End_time2 = Start_time2 + time_filtering/1e6
Start_time3 = 25.7
End_time3 = Start_time3 + time_filtering/1e6
Start_time4 = 37.7
End_time4 = Start_time4 + time_filtering/1e6
Start_time5 = 49.7
End_time5 = Start_time5 + time_filtering/1e6
Start_time6 = 61.2
End_time6 = Start_time6 + time_filtering/1e6
Start_time7 = 72.7
End_time7 = Start_time7 + time_filtering/1e6
Start_time8 = 85.2
End_time8 = Start_time8 + time_filtering/1e6
Start_time9 = 98.2
End_time9 = Start_time9 + time_filtering/1e6

# Number of bins and binwidth for correlation measurement
number = int(750 * 1.7)
binwidth_corr = 200 * 1e3

# Number of bins and binwidth for histogram measurement
number_bins = 460 * 16
binwidth_hist = 125 * 1e3 / 8

# The defination of all channels
trigger_channel = 2
PMT_channel1 = 1
PMT_channel2 = 3

# g2_data_path
g2_data_path = "D:/Data Storage/Multiplexing/g2_data/"

all_raw_data = ["filewriterDate 2024-01-13, Time 12-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-47_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-29_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 15-33_9_ions.1.ttbin"]

# all_raw_data = ["filewriterDate 2024-01-13, Time 15-2_9_ions.1.ttbin"]

raw_data = ["filewriterDate 2024-01-13, Time 12-27_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 13-5_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 13-40_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 15-2_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 19-47_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 19-29_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin"]

# all_raw_data = ["filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin"]

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in all_raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                             open_gate_channel2,
                                                             open_gate_channel3,
                                                             open_gate_channel4,
                                                             open_gate_channel5,
                                                             open_gate_channel6,
                                                             open_gate_channel7,
                                                             open_gate_channel8,
                                                             open_gate_channel9])
    open_gate_channel = open_gate.getChannel()

    close_gate = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel, delay=time_filtering)
    close_gate_channel = close_gate.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

    # np.save('corr.getData_'+formatted_string+'.npy', corr.getData())
    # np.save('corr.getIndex_'+formatted_string+'.npy', corr.getIndex())

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

# Plot the g(2) function
# np.save('data_final_corr_meas_'+formatted_string+'.npy', final_result)
# np.save('index_final_corr_meas_'+formatted_string+'.npy', index)

plt.figure(figsize = (10, 5))
plt.plot(index, final_result)
plt.title("9 ions coincidence counts", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

title = "Histogram with 9 ions and addressing laser"
'''plt.plot'''
plt.figure(figsize = (20, 10))
plt.rc('font',family='STIXGeneral')
plt.scatter(hist_index, final_hist, c='C0')
plt.plot(hist_index, final_hist, c='C0')

plt.axvline(Start_time1, color='r')
print("Start time =", Start_time1, "us")
plt.axvline(End_time1, color='r')
print("End time =", End_time1, "us")

plt.axvline(Start_time2, color='r')
print("Start time =", Start_time2, "us")
plt.axvline(End_time2, color='r')
print("End time =", End_time2, "us")

plt.axvline(Start_time3, color='r')
print("Start time =", Start_time3, "us")
plt.axvline(End_time3, color='r')
print("End time =", End_time3, "us")

plt.axvline(Start_time4, color='r')
print("Start time =", Start_time4, "us")
plt.axvline(End_time4, color='r')
print("End time =", End_time4, "us")

plt.axvline(Start_time5, color='r')
print("Start time =", Start_time5, "us")
plt.axvline(End_time5, color='r')
print("End time =", End_time5, "us")

plt.axvline(Start_time6, color='r')
print("Start time =", Start_time6, "us")
plt.axvline(End_time6, color='r')
print("End time =", End_time6, "us")

plt.axvline(Start_time7, color='r')
print("Start time =", Start_time7, "us")
plt.axvline(End_time7, color='r')
print("End time =", End_time7, "us")

plt.axvline(Start_time8, color='r')
print("Start time =", Start_time8, "us")
plt.axvline(End_time8, color='r')
print("End time =", End_time8, "us")

plt.axvline(Start_time9, color='r')
print("Start time =", Start_time9, "us")
plt.axvline(End_time9, color='r')
print("End time =", End_time9, "us")

# plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.title("all ions hist", fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
# plt.xlim(Start_time1-2, End_time1+2)
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
# plt.savefig('./'+file_name_PMT+' _data.jpg')
plt.show()
# Out:
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-38
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Start time = 0.7 us
# End time = 1.0 us
# Start time = 13.7 us
# End time = 14.0 us
# Start time = 25.7 us
# End time = 26.0 us
# Start time = 37.7 us
# End time = 38.0 us
# Start time = 49.7 us
# End time = 50.0 us
# Start time = 61.2 us
# End time = 61.5 us
# Start time = 72.7 us
# End time = 73.0 us
# Start time = 85.2 us
# End time = 85.5 us
# Start time = 98.2 us
# End time = 98.5 us

# %%
# Redefine the windows for binning based on the corrected start and end times
# Load the index and the data from the provided .npy files
# index_data = np.load('index_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
# counts_data = np.load('data_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
counts_data = final_result
index_data = index

bin_windows = [
    (-98.0, -92.0),
    (-86.0, -80.0),
    (-74.0, -68.0),
    (-62.0, -56.0),
    (-50.0, -44.0),
    (-39.0, -32.0),
    (-27.0, -21.0),
    (-15.0, -9.0),
    (-2.0, 2.0),
    (9.0, 15.0),
    (21.0, 27.0),
    (33.0, 39.0),
    (43.0, 51.0),
    (56.0, 62.0),
    (68.0, 74.0),
    (80.0, 86.0),
    (92.0, 98.0)
]

np.save("non_binned_counts_20240113", counts_data)

# counts_data = np.load("non_binned_counts_20240111.npy") + \
#               np.load("non_binned_counts_20240112.npy") + \
#               np.load("non_binned_counts_20240113.npy") + \
#               np.load("non_binned_counts_20240114.npy") + \
#               np.load("non_binned_counts_20240115.npy")

plt.figure(figsize = (10, 5))
plt.rc('font',family='STIXGeneral')
plt.plot(index_data, counts_data, c='C0')
plt.scatter(index_data, counts_data, c='C0')

for i in range(len(bin_windows)):
    plt.axvline(bin_windows[i][0], color='r')
    print("Start time =", bin_windows[i][0], "us")
    plt.axvline(bin_windows[i][1], color='r')
    print("End time =", bin_windows[i][1], "us")

plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
plt.show()

# Re-bin the data according to the new specified windows
binned_counts = []

for start, end in bin_windows:
    # Find indices where the delay is within the current window (considering negative windows)
    indices_in_window = (index_data >= start) & (index_data <= end) if start < end else (index_data <= start) & (index_data >= end)
    # Sum the counts for these indices
    counts_sum = counts_data[indices_in_window].sum()
    binned_counts.append(counts_sum)

np.save("binned_counts_20240113", binned_counts)

# binned_counts = np.load("binned_counts_20240111.npy") + \
#                 np.load("binned_counts_20240112.npy") + \
#                 np.load("binned_counts_20240113.npy") + \
#                 np.load("binned_counts_20240114.npy") + \
#                 np.load("binned_counts_20240115.npy")

# Re-plotting the binned data with the corrected windows
plt.figure(figsize=(10, 6))
# x_labels = [f"{start}-{end}" for (start, end) in bin_windows]
# window_num = np.array(range(19)) - 9
# x_labels = [f"window {i}" for i in window_num]
x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=17)

print(len(x_labels))
print(len(binned_counts))

plt.bar(x_labels, binned_counts, color='C0', width=2)

x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=200)
plt.bar(x_labels, np.zeros(200), color='C0', width=2)

# plt.plot(x_labels, binned_counts, color='C0')
plt.xlabel('Delay time (us)')
plt.ylabel('Correlation counts')
plt.title('Single photon correlation counts', fontdict={'family' : 'STIXGeneral', 'size':25})
# plt.xticks(x_labels[::3])   #,  rotation='vertical'
# plt.xticks(rotation=90)  # Rotate the labels to prevent overlap due to increased number of bins
plt.tight_layout()  # Adjust the plot to ensure everything fits without overlapping
plt.show()
print(binned_counts)
# Out:
# Start time = -98.0 us
# End time = -92.0 us
# Start time = -86.0 us
# End time = -80.0 us
# Start time = -74.0 us
# End time = -68.0 us
# Start time = -62.0 us
# End time = -56.0 us
# Start time = -50.0 us
# End time = -44.0 us
# Start time = -39.0 us
# End time = -32.0 us
# Start time = -27.0 us
# End time = -21.0 us
# Start time = -15.0 us
# End time = -9.0 us
# Start time = -2.0 us
# End time = 2.0 us
# Start time = 9.0 us
# End time = 15.0 us
# Start time = 21.0 us
# End time = 27.0 us
# Start time = 33.0 us
# End time = 39.0 us
# Start time = 43.0 us
# End time = 51.0 us
# Start time = 56.0 us
# End time = 62.0 us
# Start time = 68.0 us
# End time = 74.0 us
# Start time = 80.0 us
# End time = 86.0 us
# Start time = 92.0 us
# End time = 98.0 us
# 17
# 17
# [8.0, 18.0, 7.0, 12.0, 4.0, 10.0, 18.0, 14.0, 2.0, 21.0, 18.0, 14.0, 4.0, 16.0, 14.0, 14.0, 8.0]

# %% [markdown]
# ### Data on 20240114

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# offset = 0

# Start_time1 = 0.0
# End_time1 = 2
# Start_time2 = 13.0
# End_time2 = 15
# Start_time3 = 25.0
# End_time3 = 27
# Start_time4 = 37.0
# End_time4 = 39
# Start_time5 = 49.0
# End_time5 = 51
# Start_time6 = 60.5
# End_time6 = 62.5
# Start_time7 = 72.0
# End_time7 = 74
# Start_time8 = 85.0
# End_time8 = 87.0
# Start_time9 = 97.5
# End_time9 = 99.5

# Time filtering window length
# time_filtering = (1 + offset) * 1e6
time_filtering = (0.3) * 1e6

offset = 0
# offset = 0

Start_time1 = 1.95
End_time1 = Start_time1 + time_filtering/1e6
Start_time2 = 14.17
End_time2 = Start_time2 + time_filtering/1e6
Start_time3 = 25.7
End_time3 = Start_time3 + time_filtering/1e6
Start_time4 = 38.2
End_time4 = Start_time4 + time_filtering/1e6
Start_time5 = 49.95
End_time5 = Start_time5 + time_filtering/1e6
Start_time6 = 61.7
End_time6 = Start_time6 + time_filtering/1e6
Start_time7 = 73.2
End_time7 = Start_time7 + time_filtering/1e6
Start_time8 = 85.45
End_time8 = Start_time8 + time_filtering/1e6
Start_time9 = 98.7
End_time9 = Start_time9 + time_filtering/1e6

# Number of bins and binwidth for correlation measurement
number = int(750 * 1.7)
binwidth_corr = 200 * 1e3

# Number of bins and binwidth for histogram measurement
number_bins = 460 * 16
binwidth_hist = 125 * 1e3 / 8

# The defination of all channels
trigger_channel = 2
PMT_channel1 = 1
PMT_channel2 = 3

# g2_data_path
g2_data_path = "D:/Data Storage/Multiplexing/g2_data/"

all_raw_data = ["filewriterDate 2024-01-14, Time 15-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 15-45_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 16-4_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 16-11_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 16-30_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 16-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 17-16_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 17-35_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 17-58_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 18-17_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 18-37_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 20-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 20-31_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 20-50_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 21-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 21-51_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 22-32_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 23-0_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 23-21_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 23-44_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 0-4_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 0-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 11-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-1_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-22_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-40_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-59_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 14-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 15-13_9_ions.1.ttbin"]

all_raw_data = ["filewriterDate 2024-01-14, Time 15-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 15-45_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 16-4_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 16-11_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 16-30_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 16-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 17-16_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 17-35_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 17-58_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 18-17_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 18-37_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 20-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 20-31_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 20-50_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 21-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 21-51_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 22-32_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 23-0_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 23-21_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 23-44_9_ions.1.ttbin"]

# all_raw_data = ["filewriterDate 2024-01-15, Time 0-4_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 0-24_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 11-5_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 13-1_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 13-22_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 13-40_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 13-59_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 14-48_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 15-13_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 15-59_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 16-33_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 16-52_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 17-12_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 17-33_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 17-52_9_ions.1.ttbin",
#                 "filewriterDate 2024-01-15, Time 18-31_9_ions.1.ttbin"]

# all_raw_data = ["filewriterDate 2024-01-14, Time 15-24_9_ions.1.ttbin"]

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in all_raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                             open_gate_channel2,
                                                             open_gate_channel3,
                                                             open_gate_channel4,
                                                             open_gate_channel5,
                                                             open_gate_channel6,
                                                             open_gate_channel7,
                                                             open_gate_channel8,
                                                             open_gate_channel9])
    open_gate_channel = open_gate.getChannel()

    close_gate = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel, delay=time_filtering)
    close_gate_channel = close_gate.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

    # np.save('corr.getData_'+formatted_string+'.npy', corr.getData())
    # np.save('corr.getIndex_'+formatted_string+'.npy', corr.getIndex())

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

# Plot the g(2) function
# np.save('data_final_corr_meas_'+formatted_string+'.npy', final_result)
# np.save('index_final_corr_meas_'+formatted_string+'.npy', index)

plt.figure(figsize = (10, 5))
plt.plot(index, final_result)
plt.title("9 ions coincidence counts", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

title = "Histogram with 9 ions and addressing laser"
'''plt.plot'''
plt.figure(figsize = (20, 10))
plt.rc('font',family='STIXGeneral')
plt.scatter(hist_index, final_hist, c='C0')
plt.plot(hist_index, final_hist, c='C0')

plt.axvline(Start_time1, color='r')
print("Start time =", Start_time1, "us")
plt.axvline(End_time1, color='r')
print("End time =", End_time1, "us")

plt.axvline(Start_time2, color='r')
print("Start time =", Start_time2, "us")
plt.axvline(End_time2, color='r')
print("End time =", End_time2, "us")

plt.axvline(Start_time3, color='r')
print("Start time =", Start_time3, "us")
plt.axvline(End_time3, color='r')
print("End time =", End_time3, "us")

plt.axvline(Start_time4, color='r')
print("Start time =", Start_time4, "us")
plt.axvline(End_time4, color='r')
print("End time =", End_time4, "us")

plt.axvline(Start_time5, color='r')
print("Start time =", Start_time5, "us")
plt.axvline(End_time5, color='r')
print("End time =", End_time5, "us")

plt.axvline(Start_time6, color='r')
print("Start time =", Start_time6, "us")
plt.axvline(End_time6, color='r')
print("End time =", End_time6, "us")

plt.axvline(Start_time7, color='r')
print("Start time =", Start_time7, "us")
plt.axvline(End_time7, color='r')
print("End time =", End_time7, "us")

plt.axvline(Start_time8, color='r')
print("Start time =", Start_time8, "us")
plt.axvline(End_time8, color='r')
print("End time =", End_time8, "us")

plt.axvline(Start_time9, color='r')
print("Start time =", Start_time9, "us")
plt.axvline(End_time9, color='r')
print("End time =", End_time9, "us")

# plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.title("all ions hist", fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
# plt.xlim(Start_time9-2, End_time9+2)
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
# plt.savefig('./'+file_name_PMT+' _data.jpg')
plt.show()
# Out:
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Date 2024-01-26, Time 16-39
# Start time = 1.95 us
# End time = 2.25 us
# Start time = 14.17 us
# End time = 14.47 us
# Start time = 25.7 us
# End time = 26.0 us
# Start time = 38.2 us
# End time = 38.5 us
# Start time = 49.95 us
# End time = 50.25 us
# Start time = 61.7 us
# End time = 62.0 us
# Start time = 73.2 us
# End time = 73.5 us
# Start time = 85.45 us
# End time = 85.75 us
# Start time = 98.7 us
# End time = 99.0 us

# %%
# Redefine the windows for binning based on the corrected start and end times
# Load the index and the data from the provided .npy files
# index_data = np.load('index_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
# counts_data = np.load('data_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
counts_data = final_result
index_data = index

bin_windows = [
    (-98.0, -92.0),
    (-86.0, -80.0),
    (-74.0, -68.0),
    (-62.0, -56.0),
    (-50.0, -44.0),
    (-39.0, -32.0),
    (-27.0, -21.0),
    (-15.0, -9.0),
    (-2.0, 2.0),
    (9.0, 15.0),
    (21.0, 27.0),
    (33.0, 39.0),
    (43.0, 51.0),
    (56.0, 62.0),
    (68.0, 74.0),
    (80.0, 86.0),
    (92.0, 98.0)
]

np.save("non_binned_counts_20240114", counts_data)

# counts_data = np.load("non_binned_counts_20240111.npy") + \
#               np.load("non_binned_counts_20240112.npy") + \
#               np.load("non_binned_counts_20240113.npy") + \
#               np.load("non_binned_counts_20240114.npy") + \
#               np.load("non_binned_counts_20240115.npy")

plt.figure(figsize = (10, 5))
plt.rc('font',family='STIXGeneral')
plt.plot(index_data, counts_data, c='C0')
plt.scatter(index_data, counts_data, c='C0')

for i in range(len(bin_windows)):
    plt.axvline(bin_windows[i][0], color='r')
    print("Start time =", bin_windows[i][0], "us")
    plt.axvline(bin_windows[i][1], color='r')
    print("End time =", bin_windows[i][1], "us")

plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
plt.show()

# Re-bin the data according to the new specified windows
binned_counts = []

for start, end in bin_windows:
    # Find indices where the delay is within the current window (considering negative windows)
    indices_in_window = (index_data >= start) & (index_data <= end) if start < end else (index_data <= start) & (index_data >= end)
    # Sum the counts for these indices
    counts_sum = counts_data[indices_in_window].sum()
    binned_counts.append(counts_sum)

np.save("binned_counts_20240114", binned_counts)

# binned_counts = np.load("binned_counts_20240111.npy") + \
#                 np.load("binned_counts_20240112.npy") + \
#                 np.load("binned_counts_20240113.npy") + \
#                 np.load("binned_counts_20240114.npy") + \
#                 np.load("binned_counts_20240115.npy")

# Re-plotting the binned data with the corrected windows
plt.figure(figsize=(10, 6))
# x_labels = [f"{start}-{end}" for (start, end) in bin_windows]
# window_num = np.array(range(19)) - 9
# x_labels = [f"window {i}" for i in window_num]
x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=17)

print(len(x_labels))
print(len(binned_counts))

plt.bar(x_labels, binned_counts, color='C0', width=2)

x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=200)
plt.bar(x_labels, np.zeros(200), color='C0', width=2)

# plt.plot(x_labels, binned_counts, color='C0')
plt.xlabel('Delay time (us)')
plt.ylabel('Correlation counts')
plt.title('Single photon correlation counts', fontdict={'family' : 'STIXGeneral', 'size':25})
# plt.xticks(x_labels[::3])   #,  rotation='vertical'
# plt.xticks(rotation=90)  # Rotate the labels to prevent overlap due to increased number of bins
plt.tight_layout()  # Adjust the plot to ensure everything fits without overlapping
plt.show()
print(binned_counts)
# Out:
# Start time = -98.0 us
# End time = -92.0 us
# Start time = -86.0 us
# End time = -80.0 us
# Start time = -74.0 us
# End time = -68.0 us
# Start time = -62.0 us
# End time = -56.0 us
# Start time = -50.0 us
# End time = -44.0 us
# Start time = -39.0 us
# End time = -32.0 us
# Start time = -27.0 us
# End time = -21.0 us
# Start time = -15.0 us
# End time = -9.0 us
# Start time = -2.0 us
# End time = 2.0 us
# Start time = 9.0 us
# End time = 15.0 us
# Start time = 21.0 us
# End time = 27.0 us
# Start time = 33.0 us
# End time = 39.0 us
# Start time = 43.0 us
# End time = 51.0 us
# Start time = 56.0 us
# End time = 62.0 us
# Start time = 68.0 us
# End time = 74.0 us
# Start time = 80.0 us
# End time = 86.0 us
# Start time = 92.0 us
# End time = 98.0 us
# 17
# 17
# [48.0, 21.0, 41.0, 37.0, 42.0, 43.0, 61.0, 47.0, 2.0, 58.0, 66.0, 30.0, 41.0, 53.0, 23.0, 27.0, 32.0]

# %% [markdown]
# ### Data on 20240115

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 12,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 12,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 12,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# offset = 0

# Start_time1 = 0.0
# End_time1 = 2
# Start_time2 = 13.0
# End_time2 = 15
# Start_time3 = 25.0
# End_time3 = 27
# Start_time4 = 37.0
# End_time4 = 39
# Start_time5 = 49.0
# End_time5 = 51
# Start_time6 = 60.5
# End_time6 = 62.5
# Start_time7 = 72.0
# End_time7 = 74
# Start_time8 = 85.0
# End_time8 = 87.0
# Start_time9 = 97.5
# End_time9 = 99.5

# Time filtering window length
# time_filtering = (1 + offset) * 1e6
time_filtering = (0.3) * 1e6

offset = 0
# offset = 0

Start_time1 = 1.95
End_time1 = Start_time1 + time_filtering/1e6
Start_time2 = 14.22
End_time2 = Start_time2 + time_filtering/1e6
Start_time3 = 25.7
End_time3 = Start_time3 + time_filtering/1e6
Start_time4 = 38.2
End_time4 = Start_time4 + time_filtering/1e6
Start_time5 = 49.95
End_time5 = Start_time5 + time_filtering/1e6
Start_time6 = 61.7
End_time6 = Start_time6 + time_filtering/1e6
Start_time7 = 73.2
End_time7 = Start_time7 + time_filtering/1e6
Start_time8 = 85.45
End_time8 = Start_time8 + time_filtering/1e6
Start_time9 = 98.7
End_time9 = Start_time9 + time_filtering/1e6

# Number of bins and binwidth for correlation measurement
number = int(750 * 1.7)
binwidth_corr = 200 * 1e3

# Number of bins and binwidth for histogram measurement
number_bins = 460 * 16
binwidth_hist = 125 * 1e3 / 8

# The defination of all channels
trigger_channel = 2
PMT_channel1 = 1
PMT_channel2 = 3

# g2_data_path
g2_data_path = "D:/Data Storage/Multiplexing/g2_data/"

all_raw_data = ["filewriterDate 2024-01-15, Time 0-4_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 0-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 11-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-1_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-22_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-40_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-59_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 14-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 15-13_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 15-59_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 16-33_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 16-52_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 17-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 17-33_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 17-52_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 18-31_9_ions.1.ttbin"]

# all_raw_data = ["filewriterDate 2024-01-15, Time 0-4_9_ions.1.ttbin"]

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in all_raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                             open_gate_channel2,
                                                             open_gate_channel3,
                                                             open_gate_channel4,
                                                             open_gate_channel5,
                                                             open_gate_channel6,
                                                             open_gate_channel7,
                                                             open_gate_channel8,
                                                             open_gate_channel9])
    open_gate_channel = open_gate.getChannel()

    close_gate = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel, delay=time_filtering)
    close_gate_channel = close_gate.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

    # np.save('corr.getData_'+formatted_string+'.npy', corr.getData())
    # np.save('corr.getIndex_'+formatted_string+'.npy', corr.getIndex())

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

# Plot the g(2) function
# np.save('data_final_corr_meas_'+formatted_string+'.npy', final_result)
# np.save('index_final_corr_meas_'+formatted_string+'.npy', index)

plt.figure(figsize = (10, 5))
plt.plot(index, final_result)
plt.title("9 ions coincidence counts", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

title = "Histogram with 9 ions and addressing laser"
'''plt.plot'''
plt.figure(figsize = (20, 10))
plt.rc('font',family='STIXGeneral')
plt.scatter(hist_index, final_hist, c='C0')
plt.plot(hist_index, final_hist, c='C0')

plt.axvline(Start_time1, color='r')
print("Start time =", Start_time1, "us")
plt.axvline(End_time1, color='r')
print("End time =", End_time1, "us")

plt.axvline(Start_time2, color='r')
print("Start time =", Start_time2, "us")
plt.axvline(End_time2, color='r')
print("End time =", End_time2, "us")

plt.axvline(Start_time3, color='r')
print("Start time =", Start_time3, "us")
plt.axvline(End_time3, color='r')
print("End time =", End_time3, "us")

plt.axvline(Start_time4, color='r')
print("Start time =", Start_time4, "us")
plt.axvline(End_time4, color='r')
print("End time =", End_time4, "us")

plt.axvline(Start_time5, color='r')
print("Start time =", Start_time5, "us")
plt.axvline(End_time5, color='r')
print("End time =", End_time5, "us")

plt.axvline(Start_time6, color='r')
print("Start time =", Start_time6, "us")
plt.axvline(End_time6, color='r')
print("End time =", End_time6, "us")

plt.axvline(Start_time7, color='r')
print("Start time =", Start_time7, "us")
plt.axvline(End_time7, color='r')
print("End time =", End_time7, "us")

plt.axvline(Start_time8, color='r')
print("Start time =", Start_time8, "us")
plt.axvline(End_time8, color='r')
print("End time =", End_time8, "us")

plt.axvline(Start_time9, color='r')
print("Start time =", Start_time9, "us")
plt.axvline(End_time9, color='r')
print("End time =", End_time9, "us")

# plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':25})
plt.title("all ions hist", fontdict={'family' : 'STIXGeneral', 'size':25})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':20})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':20})
# plt.xlim(Start_time1-2, End_time1+2)
plt.yticks(fontproperties='STIXGeneral', size=15)
plt.xticks(fontproperties='STIXGeneral', size=15)
plt.grid(True)
# plt.savefig('./'+file_name_PMT+' _data.jpg')
plt.show()
# Out:
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Start time = 1.95 us
# End time = 2.25 us
# Start time = 14.22 us
# End time = 14.520000000000001 us
# Start time = 25.7 us
# End time = 26.0 us
# Start time = 38.2 us
# End time = 38.5 us
# Start time = 49.95 us
# End time = 50.25 us
# Start time = 61.7 us
# End time = 62.0 us
# Start time = 73.2 us
# End time = 73.5 us
# Start time = 85.45 us
# End time = 85.75 us
# Start time = 98.7 us
# End time = 99.0 us

# %%
matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 12,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 12,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 12,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# Redefine the windows for binning based on the corrected start and end times
# Load the index and the data from the provided .npy files
# index_data = np.load('index_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
# counts_data = np.load('data_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
counts_data = final_result
index_data = index

bin_windows = [
    (-98.0, -92.0),
    (-86.0, -80.0),
    (-74.0, -68.0),
    (-62.0, -56.0),
    (-50.0, -44.0),
    (-39.0, -32.0),
    (-27.0, -21.0),
    (-15.0, -9.0),
    (-2.0, 2.0),
    (9.0, 15.0),
    (21.0, 27.0),
    (33.0, 39.0),
    (43.0, 51.0),
    (56.0, 62.0),
    (68.0, 74.0),
    (80.0, 86.0),
    (92.0, 98.0)
]

np.save("non_binned_counts_20240115", counts_data)

# counts_data = np.load("non_binned_counts_20240111.npy") + \
#               np.load("non_binned_counts_20240112.npy") + \
#               np.load("non_binned_counts_20240113.npy") + \
#               np.load("non_binned_counts_20240114.npy") + \
#               np.load("non_binned_counts_20240115.npy")

plt.figure(figsize = (10, 5))
plt.rc('font',family='STIXGeneral')
plt.plot(index_data, counts_data, c='C0')
plt.scatter(index_data, counts_data, c='C0')

for i in range(len(bin_windows)):
    plt.axvline(bin_windows[i][0], color='r')
    print("Start time =", bin_windows[i][0], "us")
    plt.axvline(bin_windows[i][1], color='r')
    print("End time =", bin_windows[i][1], "us")

plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':12})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':12})
plt.ylabel('Counts', fontdict={'family' : 'STIXGeneral', 'size':12})
plt.yticks(fontproperties='STIXGeneral', size=12)
plt.xticks(fontproperties='STIXGeneral', size=12)
plt.grid(True)
plt.show()

# Re-bin the data according to the new specified windows
binned_counts = []

for start, end in bin_windows:
    # Find indices where the delay is within the current window (considering negative windows)
    indices_in_window = (index_data >= start) & (index_data <= end) if start < end else (index_data <= start) & (index_data >= end)
    # Sum the counts for these indices
    counts_sum = counts_data[indices_in_window].sum()
    binned_counts.append(counts_sum)

np.save("binned_counts_20240115", binned_counts)

# binned_counts = np.load("binned_counts_20240111.npy") + \
#                 np.load("binned_counts_20240112.npy") + \
#                 np.load("binned_counts_20240113.npy") + \
#                 np.load("binned_counts_20240114.npy") + \
#                 np.load("binned_counts_20240115.npy")

# Re-plotting the binned data with the corrected windows
half_column_width_inches = 4.25
aspect_ratio = 2  # You can adjust this for your desired aspect ratio
plt.figure(figsize=(half_column_width_inches, half_column_width_inches / aspect_ratio))
# x_labels = [f"{start}-{end}" for (start, end) in bin_windows]
# window_num = np.array(range(19)) - 9
# x_labels = [f"window {i}" for i in window_num]
x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=17)

print(len(x_labels))
print(len(binned_counts))

plt.bar(x_labels, binned_counts, color='C0', width=2)

x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=200)
plt.bar(x_labels, np.zeros(200), color='C0', width=2)

# plt.plot(x_labels, binned_counts, color='C0')
plt.xlabel(r'Delay time ($\mu$$s$)', fontdict={'family' : 'STIXGeneral', 'size':12})
plt.ylabel('Correlation counts', fontdict={'family' : 'STIXGeneral', 'size':12})
# plt.title('Single photon correlation counts', fontdict={'family' : 'STIXGeneral', 'size':12})
# plt.xticks(x_labels[::3])   #,  rotation='vertical'
# plt.xticks(rotation=90)  # Rotate the labels to prevent overlap due to increased number of bins
plt.tight_layout()  # Adjust the plot to ensure everything fits without overlapping
plt.show()
print(binned_counts)

np.save("final_result_shuttling_9_ion_chain.npy", final_result)
# Out:
# Start time = -98.0 us
# End time = -92.0 us
# Start time = -86.0 us
# End time = -80.0 us
# Start time = -74.0 us
# End time = -68.0 us
# Start time = -62.0 us
# End time = -56.0 us
# Start time = -50.0 us
# End time = -44.0 us
# Start time = -39.0 us
# End time = -32.0 us
# Start time = -27.0 us
# End time = -21.0 us
# Start time = -15.0 us
# End time = -9.0 us
# Start time = -2.0 us
# End time = 2.0 us
# Start time = 9.0 us
# End time = 15.0 us
# Start time = 21.0 us
# End time = 27.0 us
# Start time = 33.0 us
# End time = 39.0 us
# Start time = 43.0 us
# End time = 51.0 us
# Start time = 56.0 us
# End time = 62.0 us
# Start time = 68.0 us
# End time = 74.0 us
# Start time = 80.0 us
# End time = 86.0 us
# Start time = 92.0 us
# End time = 98.0 us
# 17
# 17
# [9.0, 11.0, 18.0, 16.0, 31.0, 33.0, 30.0, 36.0, 2.0, 30.0, 24.0, 23.0, 26.0, 20.0, 6.0, 12.0, 15.0]

# %%
matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 12,
         "xtick.direction": "in",
         "xtick.major.pad": 3,
         "xtick.top": True,
         "ytick.labelsize": 12,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 12,
         "axes.labelpad": 3,
         "axes.grid": True
    }
)

final_result = np.load("final_result_shuttling_9_ion_chain.npy")

# Redefine the windows for binning based on the corrected start and end times
# Load the index and the data from the provided .npy files
# index_data = np.load('index_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
# counts_data = np.load('data_final_corr_meas_Date 2024-01-12, Time 14-50.npy')
counts_data = final_result
index_data = index

bin_windows = [
    (-98.0, -92.0),
    (-86.0, -80.0),
    (-74.0, -68.0),
    (-62.0, -56.0),
    (-50.0, -44.0),
    (-39.0, -32.0),
    (-27.0, -21.0),
    (-15.0, -9.0),
    (-2.0, 2.0),
    (9.0, 15.0),
    (21.0, 27.0),
    (33.0, 39.0),
    (43.0, 51.0),
    (56.0, 62.0),
    (68.0, 74.0),
    (80.0, 86.0),
    (92.0, 98.0)
]

binned_counts = np.load("binned_counts_20240111.npy") + \
                np.load("binned_counts_20240112.npy") + \
                np.load("binned_counts_20240113.npy") + \
                np.load("binned_counts_20240114.npy") + \
                np.load("binned_counts_20240115.npy")

# Re-plotting the binned data with the corrected windows
half_column_width_inches = 4.25
aspect_ratio = 2  # You can adjust this for your desired aspect ratio
plt.figure(figsize=(half_column_width_inches, half_column_width_inches / aspect_ratio))
# x_labels = [f"{start}-{end}" for (start, end) in bin_windows]
# window_num = np.array(range(19)) - 9
# x_labels = [f"window {i}" for i in window_num]
# x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=17)
x_labels = np.linspace(-8, 8, num=17)

print(len(x_labels))
print(len(binned_counts))

plt.bar(x_labels, binned_counts / 134.5, color='C0', width=0.2)

# x_labels = np.linspace((bin_windows[0][0]+bin_windows[0][1])/2, (bin_windows[-1][0]+bin_windows[-1][1])/2, num=200)
plt.bar(x_labels, np.zeros(len(x_labels)), color='C0', width=0.1)
plt.yscale('log')  # Set log scale for Y-axis

# plt.plot(x_labels, binned_counts, color='C0')
# plt.xlabel(r'Delay time ($\mu$$s$)', fontdict={'family' : 'STIXGeneral', 'size':12})
plt.xlabel("Mode number n", fontdict={'family' : 'STIXGeneral', 'size':12})
plt.ylabel(r'Log scale $g^{(2)}$', fontdict={'family' : 'STIXGeneral', 'size':12})
# plt.title('Single photon correlation counts (static ion chain)', fontdict={'family' : 'STIXGeneral', 'size':12})
# plt.xticks(x_labels[::3])   #,  rotation='vertical'
# plt.xticks(rotation=90)  # Rotate the labels to prevent overlap due to increased number of bins
plt.tight_layout()  # Adjust the plot to ensure everything fits without overlapping
pdf_filename = 'Fig_3_a.pdf'  # Specify the path and filename you wish to use
plt.savefig(pdf_filename, format='pdf')
plt.show()
print(binned_counts / 134.5)
# Out:
# 17
# 17
# [0.61710037 0.54275093 0.57992565 0.63197026 0.75836431 0.88475836
#  1.01115242 0.98884758 0.05947955 1.01115242 1.07063197 0.65427509
#  0.72118959 0.81784387 0.55762082 0.44609665 0.49814126]

# %% [markdown]
# ### Single photon histogram

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# Time filtering window length
# time_filtering = (1 + offset) * 1e6
time_filtering = (0.3) * 1e6

offset = 0
# offset = 0

Start_time1 = 1.95
End_time1 = Start_time1 + time_filtering/1e6
Start_time2 = 14.22
End_time2 = Start_time2 + time_filtering/1e6
Start_time3 = 25.7
End_time3 = Start_time3 + time_filtering/1e6
Start_time4 = 38.2
End_time4 = Start_time4 + time_filtering/1e6
Start_time5 = 49.95
End_time5 = Start_time5 + time_filtering/1e6
Start_time6 = 61.7
End_time6 = Start_time6 + time_filtering/1e6
Start_time7 = 73.2
End_time7 = Start_time7 + time_filtering/1e6
Start_time8 = 85.45
End_time8 = Start_time8 + time_filtering/1e6
Start_time9 = 98.7
End_time9 = Start_time9 + time_filtering/1e6

# Number of bins and binwidth for correlation measurement
number = int(750 * 1.7)
binwidth_corr = 200 * 1e3

# Number of bins and binwidth for histogram measurement
number_bins = 460 * 16
binwidth_hist = 125 * 1e3 / 8

# The defination of all channels
trigger_channel = 2
PMT_channel1 = 1
PMT_channel2 = 3

# g2_data_path
g2_data_path = "D:/Data Storage/Multiplexing/g2_data/"

all_raw_data = ["filewriterDate 2024-01-15, Time 0-4_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 0-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 11-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-1_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-22_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-40_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 13-59_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 14-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 15-13_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 15-59_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 16-33_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 16-52_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 17-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 17-33_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 17-52_9_ions.1.ttbin",
                "filewriterDate 2024-01-15, Time 18-31_9_ions.1.ttbin"]

# all_raw_data = ["filewriterDate 2024-01-15, Time 0-4_9_ions.1.ttbin"]

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in all_raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                             open_gate_channel2,
                                                             open_gate_channel3,
                                                             open_gate_channel4,
                                                             open_gate_channel5,
                                                             open_gate_channel6,
                                                             open_gate_channel7,
                                                             open_gate_channel8,
                                                             open_gate_channel9])
    open_gate_channel = open_gate.getChannel()

    close_gate = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel, delay=time_filtering)
    close_gate_channel = close_gate.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel, gate_stop_channel=close_gate_channel)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

    # np.save('corr.getData_'+formatted_string+'.npy', corr.getData())
    # np.save('corr.getIndex_'+formatted_string+'.npy', corr.getIndex())

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

np.save("Single_photon_histogram_index.npy", hist_index)
np.save("Single_photon_histogram_data.npy", final_hist)
# Out:
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-40
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41
# Date 2024-01-26, Time 16-41

# %%
matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 12,
         "xtick.direction": "in",
         "xtick.major.pad": 3,
         "xtick.top": True,
         "ytick.labelsize": 12,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 12,
         "axes.labelpad": 3,
         "axes.grid": True
    }
)

hist_index = np.load("Single_photon_histogram_index.npy")
final_hist = np.load("Single_photon_histogram_data.npy")

title = "Histogram with 9 ions and addressing laser"
'''plt.plot'''
# Plotting
half_column_width_inches = 4.25
aspect_ratio = 2  # You can adjust this for your desired aspect ratio
plt.figure(figsize=(half_column_width_inches, half_column_width_inches / aspect_ratio))
plt.rc('font',family='STIXGeneral')
# plt.bar(hist_index, final_hist, color='C0') #, width=0.1

m = 2  # Number of elements in each bin
# Bin the data
n = len(final_hist)
num_bins = n // m
# binned_data = np.array([final_hist[i*m:(i+1)*m].sum() for i in range(num_bins)])
binned_data = final_hist
# Create a new histogram index for the binned data
binned_hist_index = np.array([hist_index[i*m:(i+1)*m].sum() for i in range(num_bins)])
binned_hist_index = hist_index
plt.bar(binned_hist_index, binned_data, color='C0', width=0.02)

print(len(binned_hist_index))
print(len(binned_data))

# plt.title(title, fontdict={'family' : 'STIXGeneral', 'size':12})
# plt.title("Temporal profile of single photon generation", fontdict={'family' : 'STIXGeneral', 'size':12})
plt.xlabel('Time (us)', fontdict={'family' : 'STIXGeneral', 'size':12})
plt.ylabel('Single photon counts', fontdict={'family' : 'STIXGeneral', 'size':12})
plt.xlim(0, 105)
plt.yticks(fontproperties='STIXGeneral', size=12)
plt.xticks(fontproperties='STIXGeneral', size=12)
plt.grid(True)
# plt.savefig('./'+file_name_PMT+' _data.jpg')
plt.show()
# Out:
# 7360
# 7360
