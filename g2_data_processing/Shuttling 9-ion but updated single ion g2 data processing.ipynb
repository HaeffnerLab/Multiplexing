# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# g2_data_path
g2_data_path = "D:/Data Storage/Multiplexing/g2_data/"

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

all_raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 16-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-30_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 12-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 13-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-39_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 18-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-29_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-47_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 12-42_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 13-10_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 9-38_9_ions.1.ttbin"]

raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 16-27_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-30_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 12-27_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 13-5_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 13-40_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 15-2_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 19-47_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 19-29_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 15-24_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 15-45_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 16-4_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 16-11_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 16-30_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 16-48_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 17-16_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 17-35_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 17-58_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 18-17_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 18-37_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 20-12_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 20-31_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 20-50_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 21-8_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 21-51_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 22-32_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 23-0_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 23-21_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 23-44_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 0-4_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 0-24_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 11-5_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 13-1_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 13-22_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 13-40_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 13-59_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 14-48_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 15-13_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 15-59_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 16-33_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 16-52_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 17-12_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 17-33_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 17-52_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 18-31_9_ions.1.ttbin"]

time_filtering = (0.3) * 1e6

offset = 0

Start_time1 = 0.7
End_time1 = Start_time1 + time_filtering/1e6
Start_time2 = 13.7
End_time2 = Start_time2 + time_filtering/1e6
Start_time3 = 25.7
End_time3 = Start_time3 + time_filtering/1e6
Start_time4 = 37.7
End_time4 = Start_time4 + time_filtering/1e6
Start_time5 = 49.7
End_time5 = Start_time5 + time_filtering/1e6
Start_time6 = 61.2
End_time6 = Start_time6 + time_filtering/1e6
Start_time7 = 72.7
End_time7 = Start_time7 + time_filtering/1e6
Start_time8 = 85.2
End_time8 = Start_time8 + time_filtering/1e6
Start_time9 = 98.18
End_time9 = Start_time9 + time_filtering/1e6

# Number of bins and binwidth for correlation measurement
number = int(750 * 1.7 * 2)
binwidth_corr = 200 * 1e3 / 2

# Number of bins and binwidth for histogram measurement
number_bins = 460 * 16
binwidth_hist = 125 * 1e3 / 8

# The defination of all channels
trigger_channel = 2
PMT_channel1 = 1
PMT_channel2 = 3

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# g2_data_path
g2_data_path = "D:/Data Storage/Multiplexing/g2_data/"

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

all_raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 16-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-30_9_ions.1.ttbin",
                "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 12-27_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 13-5_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 17-39_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 18-24_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-29_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 19-47_9_ions.1.ttbin",
                "filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 12-42_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 13-10_9_ions.1.ttbin",
                "filewriterDate 2024-01-14, Time 9-38_9_ions.1.ttbin"]

raw_data = ["filewriterDate 2024-01-11, Time 19-37_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 18-46_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 18-19_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 17-8_9_ions.1.ttbin",
            "filewriterDate 2024-01-11, Time 16-16_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 9-56_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 10-22_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 13-34_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 14-17_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 13-56_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 16-8_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 16-27_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 17-14_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 17-35_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-5_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-30_9_ions.1.ttbin",
            "filewriterDate 2024-01-12, Time 18-48_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 12-27_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 13-5_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 13-40_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 15-2_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 20-36_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 19-47_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 19-29_9_ions.1.ttbin",
            "filewriterDate 2024-01-13, Time 17-12_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 15-24_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 15-45_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 16-4_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 16-11_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 16-30_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 16-48_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 17-16_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 17-35_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 17-58_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 18-17_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 18-37_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 20-12_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 20-31_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 20-50_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 21-8_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 21-51_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 22-32_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 23-0_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 23-21_9_ions.1.ttbin",
            "filewriterDate 2024-01-14, Time 23-44_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 0-4_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 0-24_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 11-5_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 13-1_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 13-22_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 13-40_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 13-59_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 14-48_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 15-13_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 15-59_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 16-33_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 16-52_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 17-12_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 17-33_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 17-52_9_ions.1.ttbin",
            "filewriterDate 2024-01-15, Time 18-31_9_ions.1.ttbin"]

time_filtering = (0.3) * 1e6

offset = 0

Start_time1 = 0.7
End_time1 = Start_time1 + time_filtering/1e6
Start_time2 = 13.7
End_time2 = Start_time2 + time_filtering/1e6
Start_time3 = 25.7
End_time3 = Start_time3 + time_filtering/1e6
Start_time4 = 37.7
End_time4 = Start_time4 + time_filtering/1e6
Start_time5 = 49.7
End_time5 = Start_time5 + time_filtering/1e6
Start_time6 = 61.2
End_time6 = Start_time6 + time_filtering/1e6
Start_time7 = 72.7
End_time7 = Start_time7 + time_filtering/1e6
Start_time8 = 85.2
End_time8 = Start_time8 + time_filtering/1e6
Start_time9 = 98.18
End_time9 = Start_time9 + time_filtering/1e6

# Number of bins and binwidth for correlation measurement
number = int(750 * 1.7 * 2)
binwidth_corr = 200 * 1e3 / 2

# Number of bins and binwidth for histogram measurement
number_bins = 460 * 16
binwidth_hist = 125 * 1e3 / 8

# The defination of all channels
trigger_channel = 2
PMT_channel1 = 1
PMT_channel2 = 3

# Getting the current date and time
now = datetime.now()
# Extracting the date, hour, and minute
current_date = now.date()
current_hour = now.hour
current_minute = now.minute
# Converting to a char string
formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"

"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# set the counts to 0 for the delay time larger than 1 us
final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('1_final_result_left_ion_data.npy', final_result_left)
np.save('1_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# set the counts to 0 for the delay time less than 1 us
final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('1_final_result_right_ion_data.npy', final_result_right)
np.save('1_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# set the counts to 0 for the delay time less than or larger than 1 us
final_result_center[index < 1] = 0
final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('1_final_result_center_ion_data.npy', final_result_center)
np.save('1_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 19-44
# Date 2025-05-01, Time 19-44
# Date 2025-05-01, Time 19-44
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-45
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-46
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-47
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-48
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-49
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-50
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-51
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-52
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53

# %%
"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel2])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# # set the counts to 0 for the delay time larger than 1 us
# final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('2_final_result_left_ion_data.npy', final_result_left)
np.save('2_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel2])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# # set the counts to 0 for the delay time less than 1 us
# final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('2_final_result_right_ion_data.npy', final_result_right)
np.save('2_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel2])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel2])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# # set the counts to 0 for the delay time less than or larger than 1 us
# final_result_center[index < 1] = 0
# final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('2_final_result_center_ion_data.npy', final_result_center)
np.save('2_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-53
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-54
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-55
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-56
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-57
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-58
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 19-59
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-0
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1

# %%
"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel3])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# # set the counts to 0 for the delay time larger than 1 us
# final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('3_final_result_left_ion_data.npy', final_result_left)
np.save('3_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel3])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# # set the counts to 0 for the delay time less than 1 us
# final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('3_final_result_right_ion_data.npy', final_result_right)
np.save('3_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel3])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel3])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# # set the counts to 0 for the delay time less than or larger than 1 us
# final_result_center[index < 1] = 0
# final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('3_final_result_center_ion_data.npy', final_result_center)
np.save('3_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-1
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-2
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-3
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-4
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-5
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-6
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-7
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-8
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel4])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# # set the counts to 0 for the delay time larger than 1 us
# final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('4_final_result_left_ion_data.npy', final_result_left)
np.save('4_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel4])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# # set the counts to 0 for the delay time less than 1 us
# final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('4_final_result_right_ion_data.npy', final_result_right)
np.save('4_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel4])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel4])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# # set the counts to 0 for the delay time less than or larger than 1 us
# final_result_center[index < 1] = 0
# final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('4_final_result_center_ion_data.npy', final_result_center)
np.save('4_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-9
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-10
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-11
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-12
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-13
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-14
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-15
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-16
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17
# Date 2025-05-01, Time 20-17

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel5])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# # set the counts to 0 for the delay time larger than 1 us
# final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('5_final_result_left_ion_data.npy', final_result_left)
np.save('5_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel5])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# # set the counts to 0 for the delay time less than 1 us
# final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('5_final_result_right_ion_data.npy', final_result_right)
np.save('5_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel5])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel5])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# # set the counts to 0 for the delay time less than or larger than 1 us
# final_result_center[index < 1] = 0
# final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('5_final_result_center_ion_data.npy', final_result_center)
np.save('5_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-18
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-19
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-20
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-21
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-22
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-23
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-24
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-25
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel6])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# # set the counts to 0 for the delay time larger than 1 us
# final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('6_final_result_left_ion_data.npy', final_result_left)
np.save('6_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel6])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# # set the counts to 0 for the delay time less than 1 us
# final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('6_final_result_right_ion_data.npy', final_result_right)
np.save('6_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel6])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel6])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# # set the counts to 0 for the delay time less than or larger than 1 us
# final_result_center[index < 1] = 0
# final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('6_final_result_center_ion_data.npy', final_result_center)
np.save('6_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-26
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-27
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-28
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-29
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-30
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-31
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-32
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-33
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel7])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# # set the counts to 0 for the delay time larger than 1 us
# final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('7_final_result_left_ion_data.npy', final_result_left)
np.save('7_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel7])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# # set the counts to 0 for the delay time less than 1 us
# final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('7_final_result_right_ion_data.npy', final_result_right)
np.save('7_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel7])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel7])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# # set the counts to 0 for the delay time less than or larger than 1 us
# final_result_center[index < 1] = 0
# final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('7_final_result_center_ion_data.npy', final_result_center)
np.save('7_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-34
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-35
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-36
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-37
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-38
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-39
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-40
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-41
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel8])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# # set the counts to 0 for the delay time larger than 1 us
# final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('8_final_result_left_ion_data.npy', final_result_left)
np.save('8_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel8])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# # set the counts to 0 for the delay time less than 1 us
# final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('8_final_result_right_ion_data.npy', final_result_right)
np.save('8_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel8])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel8])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# # set the counts to 0 for the delay time less than or larger than 1 us
# final_result_center[index < 1] = 0
# final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('8_final_result_center_ion_data.npy', final_result_center)
np.save('8_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-42
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-43
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-44
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-45
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-46
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-47
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-48
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-49
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50

# %%
import os
import TimeTagger
import matplotlib
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

"""Processing the left side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel9])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)
    # hist = TimeTagger.Histogram(tagger=tagger, click_channel=gated_PMT_channel2.getChannel(), start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    # corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth, n_bins=n_bins)
    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_left = final_result
# # set the counts to 0 for the delay time larger than 1 us
# final_result_left[index > 1] = 0
plt.plot(index, final_result_left)
np.save('9_final_result_left_ion_data.npy', final_result_left)
np.save('9_index_left_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the right side of data"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel9])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel1,
                                                               open_gate_channel2,
                                                               open_gate_channel3,
                                                               open_gate_channel4,
                                                               open_gate_channel5,
                                                               open_gate_channel6,
                                                               open_gate_channel7,
                                                               open_gate_channel8,
                                                               open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_right = final_result
# # set the counts to 0 for the delay time less than 1 us
# final_result_right[index < 1] = 0
plt.plot(index, final_result_right)
np.save('9_final_result_right_ion_data.npy', final_result_right)
np.save('9_index_right_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()

"""Processing the center ion data for removing"""
# The Virtual Time Tagger is initialized similar to the physical one
tagger = TimeTagger.createTimeTaggerVirtual()
fig = plt.figure()

final_result = np.zeros(number)
final_hist = np.zeros(number_bins)

# The loop allows us to repeat the replay several times
for data in raw_data:
    binwidth = binwidth_corr
    n_bins = number   # Adjust number of bins as needed

    open_gate1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time1 * 1e6)
    open_gate_channel1 = open_gate1.getChannel()
    open_gate2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time2 * 1e6)
    open_gate_channel2 = open_gate2.getChannel()
    open_gate3 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time3 * 1e6)
    open_gate_channel3 = open_gate3.getChannel()
    open_gate4 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time4 * 1e6)
    open_gate_channel4 = open_gate4.getChannel()
    open_gate5 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time5 * 1e6)
    open_gate_channel5 = open_gate5.getChannel()
    open_gate6 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time6 * 1e6)
    open_gate_channel6 = open_gate6.getChannel()
    open_gate7 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time7 * 1e6)
    open_gate_channel7 = open_gate7.getChannel()
    open_gate8 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time8 * 1e6)
    open_gate_channel8 = open_gate8.getChannel()
    open_gate9 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=trigger_channel, delay=Start_time9 * 1e6)
    open_gate_channel9 = open_gate9.getChannel()

    open_gate_1 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel9])
    open_gate_channel_1 = open_gate_1.getChannel()
    close_gate_1 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_1, delay=time_filtering)
    close_gate_channel_1 = close_gate_1.getChannel()

    open_gate_2 = TimeTagger.Combiner(tagger=tagger, channels=[open_gate_channel9])
    open_gate_channel_2 = open_gate_2.getChannel()
    close_gate_2 = TimeTagger.DelayedChannel(tagger=tagger, input_channel=open_gate_channel_2, delay=time_filtering)
    close_gate_channel_2 = close_gate_2.getChannel()

    gated_PMT_channel1 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel1, gate_start_channel=open_gate_channel_2, gate_stop_channel=close_gate_channel_2)
    gated_PMT_channel2 = TimeTagger.GatedChannel(tagger=tagger, input_channel=PMT_channel2, gate_start_channel=open_gate_channel_1, gate_stop_channel=close_gate_channel_1)
    
    hist = TimeTagger.Histogram(tagger=tagger, click_channel=PMT_channel1, start_channel = trigger_channel, binwidth = binwidth_hist, n_bins = number_bins)

    corr = TimeTagger.Correlation(tagger=tagger, channel_1=gated_PMT_channel1.getChannel(), channel_2=gated_PMT_channel2.getChannel(), binwidth=binwidth_corr, n_bins=n_bins)
    # measurement_time = int(0.001 * 3600 * 1e12)  # Adjust measurement time as needed

    # In general, the data are replayed at the same speed as they have been acquired. You can modify the speed by a factor or replay them as fast es possible by speed < 0
    tagger.setReplaySpeed(speed=-1)

    # Start the replay
    filename = g2_data_path + data
    tagger.replay(file=filename)

    while not tagger.waitForCompletion(timeout=-1):
        fig.clear()
        plt.plot(corr.getIndex(), corr.getData())
        plt.xlabel("Time difference [ps]")
        plt.ylabel("Counts")
        plt.pause(.1)

    # Extracting the date, hour, and minute
    current_date = now.date()
    current_hour = now.hour
    current_minute = now.minute
    # Converting to a char string
    formatted_string = f"Date {current_date}, Time {current_hour}-{current_minute}"
    print(formatted_string)

    # Get the correlation data
    hist_data = hist.getData()
    hist_index = hist.getIndex() / 1e6
    final_hist += hist_data
    # np.save('hist_meas_'+formatted_string+'.npy', hist_index, hist_data)
    
    g2_data = corr.getData()
    index = corr.getIndex() / 1e6
    final_result += g2_data
    # np.save('corr_meas_'+formatted_string+'.npy', index, g2_data)

    # Getting the current date and time
    now = datetime.now()

# Free the TimeTagger
TimeTagger.freeTimeTagger(tagger)

plt.figure(figsize = (10, 5))
final_result_center = final_result
# # set the counts to 0 for the delay time less than or larger than 1 us
# final_result_center[index < 1] = 0
# final_result_center[index > 1] = 0
plt.plot(index, final_result_center)
np.save('9_final_result_center_ion_data.npy', final_result_center)
np.save('9_index_center_ion_data.npy', index)
plt.title("coincidence counts for the first ion", fontdict={'size':20})
plt.xlabel("Delay (us)")
plt.ylabel("Counts")
plt.show()
# Out:
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-50
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-51
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-52
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-53
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-54
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-55
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-56
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-57
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-58
# Date 2025-05-01, Time 20-59
# Date 2025-05-01, Time 20-59
